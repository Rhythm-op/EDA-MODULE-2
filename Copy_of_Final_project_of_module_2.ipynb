# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
# Here’s a project summary for analyzing Amazon TV and Prime Shows using Python, with libraries like NumPy, Pandas, Matplotlib, and Seaborn.
#
# 📌 Project Title:
# Exploratory Data Analysis of Amazon Prime TV Shows
#
# 📄 Objective:
# To perform data analysis on Amazon Prime TV shows dataset using Python libraries, uncover trends, and generate insights on content availability, genres, release patterns, ratings, etc.
#
# 🧰 Python Libraries Used:
# Library	Purpose
# NumPy	For numerical operations and handling arrays
# Pandas	Data manipulation, filtering, and preprocessing
# Matplotlib	Plotting basic graphs and visualizations
# Seaborn	Advanced statistical visualizations
# Plotly (optional)	Interactive charts (optional for extended interactivity)
#
# 📂 Dataset:
# A .csv file typically containing fields like:
#
# title, genre, release_year, duration, imdb_rating, country, type, etc.
#
# 🔧 Steps in Project Workflow:
# 1. Import Libraries
# python
# Copy
# Edit
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# 2. Load and Inspect Dataset
# python
# Copy
# Edit
# df = pd.read_csv('amazon_prime_titles.csv')
# print(df.head())
# print(df.info())
# 3. Data Cleaning & Preprocessing
# Handle missing values
#
# Convert date columns
#
# Normalize genre and duration columns
#
# python
# Copy
# Edit
# df.dropna(subset=['title'], inplace=True)
# df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')
# df['duration'] = df['duration'].str.extract('(\d+)').astype('float')
# 4. Descriptive Statistics
# python
# Copy
# Edit
# print(df.describe())
# print(df['genre'].value_counts().head(10))
# 5. Visualizations
# a. 📊 Number of Shows per Year
# python
# Copy
# Edit
# sns.countplot(data=df, x='release_year', order=df['release_year'].value_counts().index[:10])
# plt.xticks(rotation=45)
# plt.title("Top 10 Years with Most Releases")
# plt.show()
# b. 📈 Genre Distribution
# python
# Copy
# Edit
# df['genre'].value_counts().head(10).plot(kind='barh')
# plt.title("Top 10 Genres on Amazon Prime")
# plt.xlabel("Number of Titles")
# plt.show()
# c. 🎯 IMDb Ratings Distribution
# python
# Copy
# Edit
# sns.histplot(df['imdb_rating'], bins=20, kde=True)
# plt.title("Distribution of IMDb Ratings")
# plt.xlabel("IMDb Rating")
# plt.show()
# 📊 Key Insights Example:
# Most shows are from 2017 to 2020.
#
# Drama and Comedy are the most common genres.
#
# Majority of shows have an IMDb rating between 6.5 and 8.0.
#
# English-language shows dominate the catalog.
#
# 📈 Impact / Use Case:
# Helps content teams to identify trends in popular genres and time periods.
#
# Assists marketing in targeting high-performing show types.
#
# Guides investment in regional content and high-rating series.
#
# 🧠 Further Improvements:
# Sentiment analysis on reviews (if available).
#
# Correlation between genre and rating.
#
# Interactive dashboards using Plotly or Power BI.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**EDA PROJECT OF MODULE 2

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.In EDA, your business objective is the main goal you're trying to achieve using data. It guides:
#
# What data you load
#
# What features you explore
#
# What visualizations you make
#
# What patterns or insights you look for
#
# ✅ Example Business Objectives in EDA
# 🛍️ Retail/E-commerce:
# “To analyze customer purchasing behavior in order to identify high-value customers and optimize marketing strategies.”
#
# 💳 Banking:
# “To explore transaction data to detect patterns that could indicate fraudulent activity.”
#
# 🏥 Healthcare:
# “To understand patient demographics and treatment outcomes to improve hospital resource allocation.”
#
# 🎓 Student Performance Dataset:
# “To identify the key factors influencing student performance to improve academic support.”
#
# ✅ How to Write One for Your EDA Project
# Use this format:
#
# “To explore [dataset/topic] to understand [specific question or goal], which will help [business impact].”
#
# ✍️ Template:
# text
# Copy
# Edit
# To explore ____________ data to understand ____________, which will help ____________.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
pip install pandas

# %%
# Import Libraries
import pandas as pd #For working with dataframes.
import numpy as np          # For working with numbers and arrays
import matplotlib.pyplot as plt  # For creating graphs
import seaborn as sns #For working with interactive graphs

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/title.csv/titles.csv') #It is used to load the csv file in python environment known as google colab.it is also used to read csv file.
dt=pd.read_csv('/content/drive/MyDrive/credits.csv file/credits.csv') #It is also used to load the csv file in python environment known as google colab in form of dataframe.it is also used to read csv file.

# %%
df=pd.merge(dt,df) #It is used to merge the two datasets

# %%
df
# Out:
#         person_id         id           name      character      role  \
# 0           59401    ts20945     Joe Besser            Joe     ACTOR
# 1           31460    ts20945     Moe Howard            Moe     ACTOR
# 2           31461    ts20945     Larry Fine          Larry     ACTOR
# 3           21174    tm19248  Buster Keaton    Johnny Gray     ACTOR
# 4           28713    tm19248    Marion Mack  Annabelle Lee     ACTOR
# ...           ...        ...            ...            ...       ...
# 124342    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124343    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124344     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124345    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124346    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
#
#                     title   type  \
# 0       The Three Stooges   SHOW
# 1       The Three Stooges   SHOW
# 2       The Three Stooges   SHOW
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#         person_id         id           name      character      role  \
# 0           59401    ts20945     Joe Besser            Joe     ACTOR
# 1           31460    ts20945     Moe Howard            Moe     ACTOR
# 2           31461    ts20945     Larry Fine          Larry     ACTOR
# 3           21174    tm19248  Buster Keaton    Johnny Gray     ACTOR
# 4           28713    tm19248    Marion Mack  Annabelle Lee     ACTOR
# ...           ...        ...            ...            ...       ...
# 124342    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124343    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124344     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124345    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124346    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
#
#                     title   type  \
# 0       The Three Stooges   SHOW
# 1       The Three Stooges   SHOW
# 2       The Three Stooges   SHOW
# ...

# %%
df.head() #It is used to show the first five rows of the dataset df
# Out:
#    person_id       id           name      character   role              title  \
# 0      59401  ts20945     Joe Besser            Joe  ACTOR  The Three Stooges
# 1      31460  ts20945     Moe Howard            Moe  ACTOR  The Three Stooges
# 2      31461  ts20945     Larry Fine          Larry  ACTOR  The Three Stooges
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR        The General
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR        The General
#
#     type                                        description  release_year  \
# 0   SHOW  The Three Stooges were an American vaudeville ...          1934
# 1   SHOW  The Three Stooges were an American vaudeville ...          1934
# 2   SHOW  The Three Stooges were an American vaudeville ...          1934
# 3  MOVIE  During America’s Civil War, Union spies steal ...          1926
# 4  MOVIE  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# ...

# %%
df.tail() #It is used to display the last five rows of dataset df.
# Out:
#         person_id         id           name      character      role  \
# 124342    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124343    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124344     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124345    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124346    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
#
#            title   type                                        description  \
# 124342  Baikunth  MOVIE  This story is about prevalent caste problem, e...
# 124343  Baikunth  MOVIE  This story is about prevalent caste problem, e...
# 124344  Baikunth  MOVIE  This story is about prevalent caste problem, e...
# 124345  Baikunth  MOVIE  This story is about prevalent caste problem, e...
# 124346  Baikunth  MOVIE  This story is about prevalent caste problem, e...
#
#         release_year age_certification  runtime               genres  \
# ...

# %%
dt #It is used to load and print the datsaset dt.
# Out:
#         person_id         id           name      character      role
# 0           59401    ts20945     Joe Besser            Joe     ACTOR
# 1           31460    ts20945     Moe Howard            Moe     ACTOR
# 2           31461    ts20945     Larry Fine          Larry     ACTOR
# 3           21174    tm19248  Buster Keaton    Johnny Gray     ACTOR
# 4           28713    tm19248    Marion Mack  Annabelle Lee     ACTOR
# ...           ...        ...            ...            ...       ...
# 124230    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124231    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124232     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124233    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124234    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
#
# [124235 rows x 5 columns]

# %%
dt.head() #It is used to show the first five rows of the dataset dt.
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %%
dt.tail()#It is used to show the last five rows of the dataset dt
# Out:
#         person_id         id           name      character      role
# 124230    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124231    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124232     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124233    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124234    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR

# %%
dt.tail() #It is used to display the last five rows of dataset dt.
# Out:
#         person_id         id           name      character      role
# 124230    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124231    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124232     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124233    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124234    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape #It is used to show the count of rows and columns of dataset df
# Out:
# (124347, 19)

# %%
dt.shape #It is used to show the count of rows and columns of dataset dt.
# Out:
# (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info() #It is used to show the info of dataset like dtype is used the data type of column and it is used to show the column filled and not filled values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   person_id             124347 non-null  int64
#  1   id                    124347 non-null  object
#  2   name                  124347 non-null  object
#  3   character             108040 non-null  object
#  4   role                  124347 non-null  object
#  5   title                 124347 non-null  object
#  6   type                  124347 non-null  object
#  7   description           124256 non-null  object
#  8   release_year          124347 non-null  int64
#  9   age_certification     56707 non-null   object
#  10  runtime               124347 non-null  int64
#  11  genres                124347 non-null  object
#  12  production_countries  124347 non-null  object
#  13  seasons               8153 non-null    float64
# ...

# %%
dt.info() #It is used to show the info of dataset like dtype is used the data type of column and it is used to show the column filled and not filled values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(df.duplicated().sum()) #It is used to show the count of duplicate values in dataset df.
# Out:
# 168

# %%
print(dt.duplicated().sum()) #It is used to show the count of duplicate values in dataset dt.
# Out:
# 56

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum()) #It is used to calculate the sum of null values of dataset df.
# Out:
# person_id                    0
# id                           0
# name                         0
# character                16307
# role                         0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67640
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116194
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10265
# dtype: int64

# %%
print(dt.isnull().sum()) #It is used to calculate the sum of null values of dataset df.
# Out:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values
missing_counts = df.isnull().sum()#It is used to calculate the sum of null values of dataset df.
missing_counts = missing_counts[missing_counts > 0]#It is used for counting the missing values and checking whether it is positive or not.

missing_counts.plot(kind='bar', figsize=(10, 6), color='tomato') #It is used for the plotting of bar chart and adjusting of bar chart and giving colour red.
plt.title("Missing Values per Column - Titles Dataset") #It is used to show the heading of the bar chart
plt.ylabel("Number of Missing Values") #It is used for labelling the y-axis.
plt.xticks(rotation=45) #It is used for rotating the x-axis labels by 45 degree.
plt.show() #It is

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here.I know that my dataset ised for analysing prime tv shows and movies.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns #It is used to show the columns of dataset df.
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role', 'title', 'type',
#        'description', 'release_year', 'age_certification', 'runtime', 'genres',
#        'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
dt.columns #It is used to show the columns of dataset dt.
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
df.describe() #It is used to show the statistical measures like count,mean,sum,average etc of dataset df.
# Out:
#           person_id   release_year        runtime      seasons     imdb_score  \
# count  1.243470e+05  124347.000000  124347.000000  8153.000000  118296.000000
# mean   4.062528e+05    1996.233234      95.536973     2.337790       5.967783
# std    5.614483e+05      27.807050      30.166352     3.130184       1.241557
# min    1.000000e+00    1912.000000       1.000000     1.000000       1.100000
# 25%    3.899600e+04    1983.000000      83.000000     1.000000       5.200000
# 50%    1.339340e+05    2009.000000      93.000000     1.000000       6.100000
# 75%    5.711600e+05    2017.000000     109.000000     2.000000       6.800000
# max    2.371153e+06    2022.000000     540.000000    49.000000       9.900000
#
#          imdb_votes  tmdb_popularity     tmdb_score
# count  1.182720e+05    124332.000000  114082.000000
# mean   2.324281e+04        10.165321       5.992100
# std    8.840151e+04        40.739203       1.321033
# min    5.000000e+00         0.000011       0.800000
# ...

# %%
dt.describe() #It is used to show the statistical measures like count,mean,sum,average etc of dataset df.
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here Here is a Variables Description (Data Dictionary) for the two uploaded datasets: titles.csv and credits.csv.
#
# 📄 titles.csv – Description of Content Titles
# Variable Name	Data Type	Description
# id	object	Unique identifier for each title (used to link with credits.csv)
# title	object	Title name of the show or movie
# type	object	Type of content: "MOVIE" or "SHOW"
# description	object	Short description or synopsis of the title
# release_year	int64	Year of release
# age_certification	object	Age rating (e.g., "PG", "TV-MA", etc.)
# runtime	int64	Duration in minutes (movies) or total runtime (shows)
# genres	object	List of genres assigned to the title
# production_countries	object	Country or countries where the title was produced
# seasons	float64	Number of seasons (only for TV shows; NaN for movies)
# imdb_id	object	IMDB ID for reference
# imdb_score	float64	Average IMDB rating
# imdb_votes	float64	Total number of IMDB votes received
# tmdb_popularity	float64	Popularity score from TMDB (The Movie Database)
# tmdb_score	float64	TMDB rating score
#
# 👥 credits.csv – Description of Cast & Crew Information
# Variable Name	Data Type	Description
# person_id	int64	Unique identifier for each person (cast/crew)
# id	object	Title ID this person is associated with (links to titles.csv)
# name	object	Full name of the person
# character	object	Character name played (only for actors; NaN for crew)
# role	object	Role type, such as "ACTOR" or "DIRECTOR"

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique() #It is used to show the unique values of dataset df.
# Out:
# person_id               80508
# id                       8861
# name                    79758
# character               71097
# role                        2
# title                    8748
# type                        2
# description              8833
# release_year              110
# age_certification          11
# runtime                   204
# genres                   1965
# production_countries      482
# seasons                    30
# imdb_id                  8267
# imdb_score                 85
# imdb_votes               3623
# tmdb_popularity          5267
# tmdb_score                 88
# dtype: int64

# %%
dt.nunique() #It is used to show the unique values of dataset dt.
# Out:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Fill missing 'runtime' with median
df['runtime'] = df['runtime'].fillna(df['runtime'].median())

# Fill missing 'age_certification' with 'Unrated'
df['age_certification'] = df['age_certification'].fillna('Unrated')

# Drop rows where 'title' or 'release_year' is missing (essential info)
df.dropna(subset=['title', 'release_year'], inplace=True)
print(df['runtime'])
# Out:
# 0         19
# 1         19
# 2         19
# 3         78
# 4         78
#           ..
# 124342    72
# 124343    72
# 124344    72
# 124345    72
# 124346    72
# Name: runtime, Length: 124347, dtype: int64

# %%
df.drop_duplicates(subset='id', keep='first', inplace=True)
dt.drop_duplicates(inplace=True)

# %%
df
# Out:
#         person_id         id                   name           character  \
# 0           59401    ts20945             Joe Besser                 Joe
# 3           21174    tm19248          Buster Keaton         Johnny Gray
# 27          29993    tm82253              Myrna Loy    Milly Stephenson
# 58          25018    tm83884             Cary Grant        Walter Burns
# 94          14701    tm56584        Humphrey Bogart  Dixon 'Dix' Steele
# ...           ...        ...                    ...                 ...
# 124324     640078   tm822572        Bradley Gosnell                Pete
# 124329     896950   tm510327              Cory Kays              Duncan
# 124333    2084915  tm1079144                Jay Nog                Self
# 124335     193033   tm847725  Varalaxmi Sarathkumar                 NaN
# 124342    1938589  tm1054116          Sangam Shukla              Madhav
#
#          role                            title   type  \
# ...

# %%
# Convert string lists to real lists
list_columns = ['genres', 'production_countries']

for col in list_columns:
    df[col] = df[col].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])

# %%
print(list_columns)
# Out:
# ['genres', 'production_countries']

# %%
# Fill 'seasons' only for shows; set 0 for movies
df['seasons'] = df['seasons'].fillna(0).astype(int)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here. 1. Show Type Distribution
# Insight: Majority of titles are movies, fewer are TV shows.
#
# Business Value: Amazon seems to focus on one-time content consumption, possibly missing out on long-term engagement TV shows bring.
#
# 📈 2. Release Trend Over Time (Line Chart)
# Insight: Number of titles added per year has grown steadily, with a spike during 2020–2021 (pandemic era).
#
# Business Value: Indicates strategic content expansion and platform maturity.
#
# 🎭 3. Genre Popularity (Barplot)
# Insight: Genres like "Drama", "Comedy", and "Thriller" dominate the platform.
#
# Business Value: Prime is focusing on genres that have broad appeal. Could also explore less-saturated genres like Animation or Documentary.
#
# 🌍 4. Production Country Distribution
# Insight: Most content is from the US, UK, and India.
#
# Business Value: Indicates strong licensing or original production partnerships in these regions. Amazon might need to boost regional/local content in underserved areas (e.g., Latin America, Southeast Asia).
#
# 🔞 5. Age Certification Distribution
# Insight: Most titles are rated 16+ or 18+, with fewer kid-friendly titles.
#
# Business Risk: Potentially alienates family audiences; could be improved by adding more PG/Universal content.
#
# ⭐ 6. IMDb Score Distribution
# Insight: Most titles are rated between 5.5 and 7.5 on IMDb.
#
# Business Value: Moderate content quality — Amazon may need to invest more in high-rated originals or premium acquisitions.
#
# 🎭 7. Cast and Crew (from credits.csv)
# Ready to Explore: Most frequent actors, directors, or their IMDb score impact.
#
# Could analyze which actors/directors bring high-rated or popular content.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
import ast  # safer than eval

df['main_genre'] = df['genres'].apply(
    lambda x: ast.literal_eval(x)[0] if pd.notnull(x) and len(ast.literal_eval(x)) > 0 else 'Unknown'
)

# %%
genres=df['main_genre'].value_counts().head(10)

# %%
genres #It is used to show how many people watched genres in different categories.
# Out:
# main_genre
# drama            2398
# comedy           1462
# thriller         1075
# documentation     597
# horror            587
# action            479
# romance           469
# western           407
# scifi             311
# crime             281
# Name: count, dtype: int64

# %%
# Chart - 1 visualization code

plt.figure(figsize=(10,6))
sns.barplot(x=genres.values, y=genres.index,orient='h')
genres = genres.sort_values(ascending=False).head(10)

plt.title("Top 10 Most Common Genres on Amazon Prime") #It is used to highlight the heading of the chart.
plt.xlabel("Number of Titles") # It is used to mark the x-axis title
plt.ylabel("Genres") #It is used to mark the y-axis title.
plt.show()#It is used for plotting the graph of histogram and to showcase the graph.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# Because from the barplot we can conclude that the which genre is highest or lowest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer *Here* Which content type is dominant?
# You can instantly see whether Amazon Prime has more movies or TV shows.
#
# Strategy Implication:
# If movies dominate, it might suggest a stronger focus on one-off content over serialized content.
#
# Audience targeting:
# Shows which age groups (e.g., 13+, 16+, 18+, etc.) the content is targeting.
#
# Business Implication:
# More adult-rated content may attract mature audiences, while PG content could suggest a family-oriented strategy.
# Most popular genres on the platform
# E.g., if "Drama", "Action", or "Comedy" are top genres, it reflects content strategy.
#
# User Demand Insight:
# This could align with what users watch the most — helps in planning new content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here Yes. Here's how:
# 🔹 1. Content Strategy Optimization
# Insight: Identifying the most and least popular genres.
#
# Impact: Helps Amazon Prime Video invest more in genres that attract and retain users (e.g., if "Drama" and "Thriller" are top-performing, they can license or produce more of them).
#
# Result: Higher user engagement, improved customer satisfaction.
#
# 🔹 2. Audience Targeting
# Insight: Age certification distribution shows which age groups are being served.
#
# Impact: If most content is 16+ or 18+, they can see if younger age groups are underserved — an opportunity to expand the family-friendly catalog.
#
# Result: Increases user base diversity (families, kids, etc.).
#
# 🔹 3. Regional Strategy and Localization
# Insight: Most content is produced in the US and UK.
#
# Impact: If there's less content from regions like India, Brazil, or South Korea, but those markets have high user growth, this is an opportunity to localize or license more regional content.
#
# Result: Improved retention in global markets, better cultural relevance.
#
# 🔹 4. Platform Growth Over Time
# Insight: Number of new titles added each year shows growth or stagnation.
#
# Impact: Tracks if Amazon Prime is staying competitive with Netflix and Disney+.
#
# Result: Better resource planning and content budget allocation.
#
# ⚠️ Are there any insights that lead to negative growth?
# Yes — and that’s why these insights are important.
# 🔻 1. Overconcentration in Specific Genres
# Issue: If 60–70% of content is from just 2–3 genres (e.g., Drama, Thriller), it signals a lack of variety.
#
# Negative Impact: Users may churn due to "content fatigue" or not finding what they enjoy (e.g., comedy lovers might feel ignored).
#
# 🔻 2. Age Certification Bias
# Issue: If most content is 18+, younger or family audiences are alienated.
#
# Negative Impact: Misses out on massive viewership from kids/teens — competitors like Disney+ gain an edge here.
#
# 🔻 3. Regional Imbalance
# Issue: Too much content from North America, not enough from Asia, Latin America, etc.
#
# Negative Impact: In regions like India or Brazil, users won’t find relatable content — reducing local engagement and retention.
#
# 🔻 4. Low-Quality Titles
# Issue: Many titles have low IMDb scores or few votes.
#
# Negative Impact: Suggests that the catalog might be bloated with unpopular or poorly rated content, lowering perceived platform quality.
#
# ✅ Conclusion
# Positive insights help Amazon Prime double down on what works (genres, regions, audience types).
#
# Negative insights are just as valuable — they reveal blind spots or weak areas that need correction.
#
# Using both allows for smarter content investments, better user experience, and sustainable growth.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
show_type_counts = df['type'].dropna().value_counts()

# Plot
plt.figure(figsize=(6,6))
show_type_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    labels=show_type_counts.index,
    colors=['#66c2a5', '#fc8d62']
)
plt.title("Distribution of Movies and TV Shows") #It is used to highlight the heading of the chart
plt.ylabel('')  # Hide y-axis label
plt.show()#It is used for plotting the graph of histogram and to showcase the graph.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.I pick the pie chart because its easy to show how much people watch movies and tv shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here the insights that can be drawn from the chart is that it shows the divisions of categories and from the autopct it shows the decimal number because after the decimal point is written.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-the gained insights insights that help creating a positive business impact are that the it is useful when there are less categories.the insights that lead to negative growth are the that the it is not useful when there are so many categories.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

titles_per_year = df['release_year'].value_counts().sort_index() #this code is used for showing how many release year movies are there and sorting the index values in ascending order.

# Line plot to show trend
titles_per_year.plot(kind='line') #It is used for plotting the line chart
plt.title('Number of Titles Released Each Year') #It is used to highlight the heading of the chart
plt.xlabel('Year')# It is used to mark the x-axis title
plt.ylabel('Number of Titles') #It is used to mark the y-axis title.
plt.show()#It is used for plotting the graph of histogram and to showcase the graph.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I picked the line chart because it shows trends over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here Possible Insights from the Line Chart:
# ✅ 1. Content Library Growth Over Time
# Insight: A consistent upward trend suggests that Amazon Prime is adding more titles every year.
#
# Business Value: Indicates strategic expansion, more content variety — great for attracting and retaining users.
#
# ✅ 2. Peak Years
# Insight: A sharp spike in certain years (e.g., 2020 or 2021) may reflect increased content acquisition or original productions.
#
# Justification: This could be due to the COVID-19 pandemic, when streaming demand surged globally.
#
# ✅ 3. Drop or Plateau in Recent Years
# Insight: If the line dips or flattens after a certain point, it could indicate:
#
# Budget cuts
#
# Strategic focus on quality over quantity
#
# Licensing challenges
#
# Business Impact: May affect competitiveness if rivals like Netflix continue growing their libraries.
#
# ✅ 4. Historic Gaps
# Insight: Few or no titles from earlier decades (e.g., before 1980).
#
# Business Interpretation: Amazon might be focused more on modern content or lacks rights to older classics.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here Insight Analysis: Number of Titles Released Each Year
# ✅ Positive Business Impact:
# Growth Periods: The line plot shows a sharp increase in the number of titles released especially in the 2010s, which reflects a boom in content production, likely due to the rise of streaming platforms like Netflix, Amazon Prime, and others.
#
# Business Opportunity: A rising trend in recent years (up until a certain peak) suggests:
#
# High audience demand
#
# Market expansion globally
#
# Increased investment in original content
#
# Opportunity to diversify genres and regional content
#
# ⚠️ Possible Negative Impact or Warning Signs:
# Recent Decline (if any): If the line shows a dip post-2020, this could signal:
#
# Pandemic effects (halt in production during 2020–2021)
#
# Market saturation or content overload
#
# Strategic cutbacks by streaming platforms to focus on quality or reduce spending
#
# Implication: While not necessarily negative growth, such dips warrant cost-benefit analysis, tighter ROI tracking, and may indicate the need for quality over quantity in content strategy.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
import pandas as pd
import altair as alt

# Load the titles.csv file
df = pd.read_csv('/content/drive/MyDrive/title.csv/titles.csv') # Added this line

# Create a scatter plot
chart = alt.Chart(df).mark_point().encode(
    x=alt.X('id', type='nominal', title='ID'),
    y=alt.Y('release_year', title='Release Year'),
    tooltip=['id', 'release_year']
).properties(
    title='ID vs. Release Year'
).interactive()

# Save the chart as a JSON file
chart.save('id_vs_release_year_scatter_plot.json')
# Removed plt.show() as it's not applicable for Altair charts

df = df.sample(5000)  # or fewer, like 2000






# At the top of your notebook
import altair as alt
alt.data_transformers.enable('vegafusion')  # Unlocks >5000 rows

# Then continue with your chart
chart = alt.Chart(df).mark_point().encode()

# %%
# !pip install vegafusion
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 74.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 70.4 MB/s eta 0:00:00
# ...

# %%
import altair as alt
alt.data_transformers.enable('vegafusion')
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %%
import pandas as pd
import altair as alt

# Enable vegafusion
alt.data_transformers.enable('vegafusion')

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/title.csv/titles.csv')
df = df.dropna(subset=['id', 'release_year'])

# Create the chart
chart = alt.Chart(df).mark_point().encode(
    x=alt.X('id:N', title='ID'),
    y=alt.Y('release_year:Q', title='Release Year'),
    tooltip=['id', 'release_year']
).properties(
    title='ID vs. Release Year',
    width=800,
    height=400
).interactive()

# Display in Colab
chart
# Out:
# alt.Chart(...)

# %%
# !pip install "vl-convert-python>=1.6.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 29.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.Because we conclude from the scatter plot that it shows the relationship between two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
import pandas as pd
import seaborn as sns

# Load the dataset (if not already loaded)


# Plotting a histogram
plt.figure(figsize=(12, 6)) #This function is used for the size of the graph.
sns.histplot(df['release_year'], bins=30, color='skyblue', edgecolor='black',kde=True)#kde=True means that it shows the distribution of trends over time
plt.title('Histogram: Distribution of Titles Released Over the Years')#It is used to highlight the heading of the chart
plt.xlabel('Release Year')# It is used to mark the x-axis title
plt.ylabel('Frequency (Number of Titles)') #It is used to mark the y-axis title.
plt.grid(axis='y')
plt.tight_layout()#It is used for showing the chart so that can be read easily
plt.show() #It is used for plotting the graph of histogram and to showcase the graph.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.Because it is used to show the continuous numerical data,like the number of titles released over the years.
#
# It helps to:
#
# Show the distribution of data across time,
#
# Identify peaks (e.g., content booms),
#
# Spot dips or gaps (e.g., production halts),
#
# And reveal overall trends in content production.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer HereInsight Recap:
# The bars show how many titles were released in each year group.
#
# The KDE curve (smooth line) shows the estimated distribution trend.
#
# A visible peak likely indicates a surge in content production, especially in the last decade.
#
# Sharp drops (like around 2020) might signal external disruptions like the pandemic.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer HereYes, the insights gained from the histogram (and KDE plot) can help generate positive business impact.
# 📈 Positive Business Impact:
# Understanding Content Trends:
#
# The histogram clearly shows the distribution of content released over time, with a significant increase in the number of titles in the last decade.
#
# This insight confirms that audience demand and digital infrastructure have grown, and platforms are responding by investing in content creation.
#
# Strategic Planning:
#
# A steady rise in title production indicates a healthy and growing content market.
#
# Businesses (e.g., OTT platforms) can use this trend to forecast future demand, allocate budgets, and plan content releases accordingly.
#
# Timing and Targeting:
#
# Peaks in specific years can inform decisions on when to release or promote new titles, aligning with periods of historically higher content engagement.
#
# 📉 Possible Signs of Negative Growth:
# ⚠️ Drop in Content Around 2020–2021:
# Justification:
#
# A visible dip in those years likely points to COVID-19-related disruptions, which affected filming schedules, theatrical releases, and investments in new productions.
#
# Though not permanent, it reflects a vulnerability in the content supply chain.
#
# ⚠️ Saturation Risk:
# In recent years, if the number of titles plateaus or slightly dips, it could signal:
#
# Market saturation (too much content, not enough differentiation)
#
# A shift from quantity to quality, where fewer titles are released but with higher production value.
#
# Viewer fatigue, where users feel overwhelmed by the volume and find it hard to discover relevant content.
#
# 💡 Strategic Recommendations:
# Use insights to invest in high-performing genres or countries.
#
# Monitor audience feedback to avoid content overload.
#
# Plan for disruptions by building flexible production and release strategies.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_titles = df.select_dtypes(include='number')
correlation_matrix = numeric_titles.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Heatmap of Numeric Features in titles.csv")#The title is used to show the title of the plot
plt.show()#It is used for plotting the graph of heatmap and to showcase the graph.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.I chose a correlation heatmap because it is specifically designed to visualize relationships between numeric variables — here’s why it's ideal in many cases:
#
# ✅ Why a Correlation Heatmap?
# It shows relationships between variables at a glance
#
# Correlation values range from –1 to +1:
#
# +1: Perfect positive correlation
#
# 0: No correlation
#
# –1: Perfect negative correlation
#
# You can quickly see which variables move together or oppose each other.
#
# Efficient for multivariate numeric data
#
# If your dataset has multiple numeric features (like ratings, duration, release year, etc.), a heatmap gives an overview of how they interact.
#
# This helps in feature selection, dimensionality reduction, or hypothesis building.
#
# Color gradients make patterns easy to spot
#
# Strong correlations (positive or negative) stand out.
#
# Weak or no correlation appears neutral (often as light or middle colors).
#
# Used in EDA (Exploratory Data Analysis)
#
# In early data analysis steps, a heatmap helps identify:
#
# Redundancy between features
#
# Outliers or unexpected relationships
#
# Grouping potential for clustering or modeling
#
# 📊 Example Use Case
# Let’s say you have a dataset with columns like:
#
# IMDb rating
#
# duration
#
# release year
#
# popularity score
#
# A correlation heatmap lets you see things like:
#
# Does duration correlate with IMDb rating?
#
# Is there any link between release year and popularity?
#
# 🔍 When Not to Use a Correlation Heatmap
# If your data is mostly categorical (e.g., genres, countries), a heatmap won’t help.
#
# If you're only comparing two variables, a scatter plot or regression line is better.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *Answer* Here ✅ Example Insights:
# Strong Positive Correlations (> 0.7)
#
# IMDb Rating vs Number of Votes: Popular shows might also be highly rated.
#
# Popularity Score vs Number of Votes: Heavily voted titles tend to trend more.
#
# Strong Negative Correlations (< -0.7)
#
# Release Year vs Duration: Older movies might have been longer/shorter than modern ones.
#
# Age Rating vs IMDb Rating: In some cases, family content might correlate inversely with user ratings.
#
# No or Weak Correlations (≈ 0)
#
# Duration vs IMDb Rating: Length of a title may not influence how it’s rated.
#
# Release Year vs Popularity: Newer titles aren't always more popular.
#
# Redundant Features
#
# If two variables are highly correlated, you may only need one for modeling (e.g., Popularity and Number of Views).
#
# 📌 What to Look For:
# Correlation Value	Insight
# ~ +1	Strong positive relationship — both values increase together
# ~ -1	Strong negative relationship — one increases, the other decreases
# ~ 0	No linear relationship
# Clusters	Groups of variables that correlate highly with each other may represent similar behavior or underlying factors
#
# 📊 Insight Example From a Real Heatmap:
# Let’s say your heatmap shows this:
#
# Feature 1	Feature 2	Correlation
# IMDb Rating	Popularity Score	+0.82
# Duration	IMDb Rating	+0.10
# Release Year	IMDb Rating	-0.45
#
# Insights:
#
# Popular shows tend to be better rated.
#
# Longer duration doesn’t necessarily mean better rating.
#
# Older shows might be slightly better rated on average.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.We can show the trends and growth of various categories of movies and tv shows.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
# Summary:
# Load your data with pd.read_csv.
#
# Peek at the data to understand its structure and fix missing info.
#
# Convert tricky columns like genres from strings to lists.
#
# Count and analyze distributions of categories like genres and show types.
#
# Use plots to visualize insights.
#
# Look at trends over years to see growth or changes.
#
# Optionally, combine datasets to do richer analysis.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
